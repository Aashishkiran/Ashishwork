# %%
import smtplib
class MyException(Exception):
    pass
class ZeroDivisonError(Exception):
    pass
server=smtplib.SMTP_SSL("smtp.gmail.com",465)
server.login("iashishkiran@gmail.com","7972553565")
def Add(a,b,c):
    return a+b-c
def Add1(a,b,c):
    return a+b+c
def Add2(a,b,c):
    return a+b/c
def Add3(a,b,c):
    return a+b*c
def subtract(a,b,c):
    return a-b-c
def subtract1(a,b,c):
    return a-b+c
def subtract2(a,b,c):
    return a-b/c
def subtract3(a,b,c):
    return a-b*c
def Divide(a,b,c):
    try:
        if a==0 or b==0 or c==0:
            raise MyException('Divided by Zero')
    except ZeroDivisonError as ex:
            print('zero division',ex) 
    else:
        return a/b/c
def Divide1(a,b,c):
    return a/b+c
def Divide2(a,b,c):
    return a/b-c
def Divide3(a,b,c):
    return a/c*b
def Multiply(a,b,c):
    return a*b*c
def Multiply1(a,b,c):
    return a*b+c
def Multiply2(a,b,c):
    return a*b-c
def Multiply3(a,b,c):
    return a*b/c
def square(a,b,c):
    return a**2+b**2+c**2+2*a*b+b*c+c*a

num1=int(input("Enter the value of first a\n"))
try:
    if num1==0:
        raise MyException('Exception')
except MyException as ex:
    print('Value cannot be zero')
        
    server.sendmail("iashishkiran@gmail.com","mh12an13055@gmail.com","Exception occured zero value no accepted")
    
num2=int(input("Enter the value of first b\n"))
try:
    if num2==0:
        raise MyException('Exception')
except MyException as ex:
    print('Value cannot be zero')
    
    server.sendmail("iashishkiran@gmail.com","mh12an13055@gmail.com","Exception occured zero value no accepted")

num3=int(input("Enter the value of first c\n"))
try:
    if num3==0:
        raise MyException('Exception')
except MyException as ex:
    print('Value cannot be zero')
        
    server.sendmail("iashishkiran@gmail.com","mh12an13055@gmail.com","Exception occured zero value no accepted")
    
choice=input("please enter the formula\n")

if choice.isupper():
    print("Please enter formula in small letters")
    
elif choice=='a+b-c' :
    print('Formulated answer is\n', Add(num1,num2,num3))
    
elif choice=='a+b+c' :
    print('Formulated answer is\n', Add1(num1,num2,num3))

elif choice=='a+b/c' :
    print('Formulated answer is\n', Add2(num1,num2,num3))
elif choice=='a+b*c' :
    print('Formulated answer is\n', Add3(num1,num2,num3))
elif choice=='a-b-c' :
    print('Formulated answer is\n', subtract(num1,num2,num3))
elif choice=='a-b+c' :
    print('Formulated answer is\n', subtract1(num1,num2,num3))
elif choice=='a-b/c' :
    print('Formulated answer is\n', subtract2(num1,num2,num3))
elif choice=='a-b*c' :
    print('Formulated answer is\n', subtract3(num1,num2,num3))
elif choice=='a/b/c' :
        print('Formulated answer is\n', Divide(num1,num2,num3))
elif choice=='a/b+c' :
    print('Formulated answer is\n', Divide1(num1,num2,num3))
elif choice=='a/b-c' :
    print('Formulated answer is\n', Divide2(num1,num2,num3))
elif choice=='a/b*c' :
    print('Formulated answer is\n', Divide3(num1,num2,num3))
elif choice=='a*b*c' :
    print('Formulated answer is\n', Multiply(num1,num2,num3))
elif choice=='a*b+c' :
    print('Formulated answer is\n', Multiply1(num1,num2,num3))
elif choice=='a*b-c' :
    print('Formulated answer is\n', Multiply2(num1,num2,num3))
elif choice=='a*b/c' :
    print('Formulated answer is\n', Multiply3(num1,num2,num3))
elif choice=='(a+b+c)2' :
    print('Formulated answer is\n', square(num1,num2,num3))
# Out:
# Enter the value of first a
# 10
# Enter the value of first b
# 0
# Value cannot be zero
# Enter the value of first c
# 30
# please enter the formula
# a+b-c
# Formulated answer is
#  -20

# %% [markdown]
# server=smtplib.SMTP_SSL("smtp.gmail.com"
